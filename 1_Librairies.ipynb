# %% [markdown]
# # Pandas

# %% [markdown]
# ##### L'incontournable que je n'ai pas besoin de commenter

# %%
# !pip install pandas 
import pandas as pd # as pd de part la convention

# %% [markdown]
# # Itables
# #### Visualisation standard augmentée (tri sur les headers, cellule de recherche dans les valeurs et fonctions)

# %%
# !pip install itables
import itables
from itables import init_notebook_mode # import de la fonction de configuration
itables.init_notebook_mode() # applique la configuration à Jupyter

# %% [markdown]
# # NumPy
# #### Manipulation de tableaux multidimensionnels, fonctions mathémathiques et statistiques

# %%
# !pip install numpy
import numpy as pd # as np de part la convention

# %% [markdown]
# # Matplotlib
# #### Dataviz

# %%
# !pip install matplotlib
import matplotlib.pyplot as plt # as plt de part la convention

# %% [markdown]
# # Seaborn

# %% [markdown]
# #### Dataviz

# %%
# !pip install seaborn
import seaborn as sns # as sns de part la convention
# il est recommandé d'importer Matplotlib avec voir nécessaire pour l'usage de plt.show() et des fonctionnalités avancées

# %% [markdown]
# # Scikit-learn
# #### Machine learning

# %%
# !pip install sklearn
# imports nécessaires et exemple d'imports pour la régression logistique
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Requests
#
# #### Requêtes API

# %%
# !pip install requests
import requests
# ensuite on utilisera requests.get

# %% [markdown]
# # Package web scrapping

# %%
# !pip install les import + upgrade lxml
# !pip install --upgrade lxml
import os
import logging
import scrapy
from scrapy.crawler import CrawlerProcess

# %% [markdown]
# # Mplcyberpunk

# %%
#! pip install mplcyberpunk
import matplotlib.pyplot as plt
import mplcyberpunk

plt.style.use("cyberpunk")  # Active le style cyberpunk

plt.plot([1, 3, 9, 5, 2, 1, 1], marker='o')
plt.plot([4, 5, 5, 7, 9, 8, 6], marker='o')
plt.title("Graphique Matplotib Cyberpunk")

mplcyberpunk.add_glow_effects()  # Ajoute l'effet de glow

plt.show()

# %% [markdown]
# # Catppuccin

# %%
# ! pip install catppuccin
# ! pip install catppuccin[pygments]

import matplotlib.pyplot as plt
import matplotlib as mpl
import catppuccin

mpl.style.use(catppuccin.PALETTE.frappe.identifier)  # Choisissez le flavor souhaité

plt.plot([1, 3, 9, 5, 2, 1, 1], marker='o')
plt.plot([4, 5, 5, 7, 9, 8, 6], marker='o')
plt.title("Graphique Catppuccin Frappé")
plt.show()
